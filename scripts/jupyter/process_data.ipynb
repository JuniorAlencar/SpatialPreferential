# %%
from src.processing_data import processing_all_data

# %%
processing_all_data("../../data")
# Out:
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_1/dim_1/alpha_a_2.00_alpha_g_1.00/prop — nada a fazer.
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_1/dim_1/alpha_a_2.00_alpha_g_3.00/prop — nada a fazer.
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_1/dim_1/alpha_a_2.00_alpha_g_4.00/prop — nada a fazer.
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_1/dim_2/alpha_a_2.00_alpha_g_4.00/prop — nada a fazer.
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_1/dim_3/alpha_a_5.00_alpha_g_2.00/prop — nada a fazer.
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_1/dim_4/alpha_a_2.00_alpha_g_4.00/prop — nada a fazer.
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_1/dim_4/alpha_a_5.00_alpha_g_2.00/prop — nada a fazer.
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_2/dim_1/alpha_a_0.00_alpha_g_2.00/prop — nada a fazer.
# [SKIP] Sem novos arquivos em: ../../data/N_100000/m0_2/dim_1/alpha_a_1.00_alpha_g_2.00/prop — nada a fazer.
# ...
