# %%
import numpy as np
import glob, os
import pandas as pd
import matplotlib.pyplot as plt
import gzip
from tqdm.notebook import tqdm
from src.parquet_functions import update_parquets_for_N, create_manifest_from_existing_parquets, copy_tree_only_parquet_and_manifests, copy_all_parquet_and_manifests_flat

# %%
ROOT = "../../data"   # ajuste para seu diretório base real

# 1) tudo numa pasta só
copy_all_parquet_and_manifests_flat(ROOT)

# 2) espelhar árvore, mas só manifest + parquet
copy_tree_only_parquet_and_manifests(ROOT)
# Out:
# [OK] Flat copy -> /home/light/Documents/SpatialPreferential/Data_Tsallis
#      files_copied=228
# [OK] Mirrored tree (filtered) -> /home/light/Documents/SpatialPreferential/Data_Network
#      dirs_created=76 files_copied=228

# %%
# n = create_manifest_from_existing_parquets(
#     N_value=100000,
#     base_data_dir="../../data",
#     tqdm_outer=tqdm,
#     debug=True
# )
# print("manifests criados:", n)

# roda para N=100000, paralelizando extração
update_parquets_for_N(
    N_value=100000,
    base_data_dir="../../data",
    use_parallel=True,
    max_workers=4,   # recomendo 2–4 pra não explodir RAM
    tqdm_outer=tqdm,
    tqdm_inner=tqdm,
    debug=True,
    batch_size=200_000,
)
# Out:
# Combinações para N=100000:   0%|          | 0/83 [00:00<?, ?combo/s]
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_1/alpha_a_2.00_alpha_g_1.00/gml
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_1/alpha_a_2.00_alpha_g_3.00/gml
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_1/alpha_a_2.00_alpha_g_4.00/gml
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_2/alpha_a_2.00_alpha_g_4.00/gml
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_3/alpha_a_5.00_alpha_g_2.00/gml
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_4/alpha_a_2.00_alpha_g_4.00/gml
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_4/alpha_a_5.00_alpha_g_2.00/gml
# True

# %%
ROOT = "../../data"   # ajuste para seu diretório base real

# 1) tudo numa pasta só
copy_all_parquet_and_manifests_flat(ROOT)

# 2) espelhar árvore, mas só manifest + parquet
copy_tree_only_parquet_and_manifests(ROOT)
