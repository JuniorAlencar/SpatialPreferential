# %%
import numpy as np
import glob, os
import pandas as pd
import matplotlib.pyplot as plt
import gzip
from tqdm.notebook import tqdm
from IPython.display import clear_output
from src.parquet_functions import update_parquets_for_N, create_manifest_from_existing_parquets, remove_all_gml_gz, copy_all_parquet_flat_by_dim, copy_tree_only_new_parquet

# %%
ROOT = "../../data"   # ajuste para seu diretório base real

# 1) tudo numa pasta só
copy_all_parquet_flat_by_dim(ROOT)

# 2) espelhar árvore, mas só manifest + parquet
copy_tree_only_new_parquet(ROOT)

# %%
# n = create_manifest_from_existing_parquets(
#     N_value=100000,
#     base_data_dir="../../data",
#     tqdm_outer=tqdm,
#     debug=True
# )
# print("manifests criados:", n)

# roda para N=100000, paralelizando extração
update_parquets_for_N(
    N_value=100000,
    base_data_dir="../../data",
    use_parallel=True,
    max_workers=4,   # recomendo 2–4 pra não explodir RAM
    tqdm_outer=tqdm,
    tqdm_inner=tqdm,
    debug=True,
    batch_size=200_000,
)
clear_output()
# Out:
# Combinações para N=100000:   0%|          | 0/657 [00:00<?, ?combo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=0.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=0.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=0.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=0.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=0.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=0.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=0.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=0.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=1.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=1.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=1.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=1.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=1.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=1.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=1.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=1.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=10.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=10.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=10.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=10.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=10.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=10.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=10.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=10.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=12.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=12.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=12.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=12.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=12.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=12.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=12.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=12.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=14.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=14.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=14.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=14.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=14.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=14.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=14.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=14.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=15.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=15.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=15.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=15.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=15.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=15.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=15.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=15.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=16.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=16.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=16.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=16.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=16.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=16.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=16.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=16.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=18.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=18.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=18.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=18.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=18.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=18.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=18.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=18.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=2.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=2.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=2.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=2.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=2.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=2.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=2.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=2.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=20.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=20.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=20.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=20.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=20.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=20.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=20.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=20.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=21.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=21.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=21.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=21.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=21.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=21.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=21.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=21.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=24.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=24.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=24.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=24.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=24.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=24.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=24.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=24.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=27.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=27.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=27.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=27.00, ag=2.00):   0%|          | 0/9 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=27.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=27.00, ag=3.00):   0%|          | 0/9 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=27.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=27.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=28.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=28.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=28.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=28.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=28.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=28.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=28.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=28.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=3.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=3.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=3.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=3.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=3.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=3.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=3.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=3.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=32.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=32.00, ag=1.00):   0%|          | 0/6 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=32.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=32.00, ag=2.00):   0%|          | 0/2 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=32.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=32.00, ag=3.00):   0%|          | 0/4 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=32.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=32.00, ag=4.00):   0%|          | 0/2 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=36.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=36.00, ag=1.00):   0%|          | 0/2 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=36.00 | alpha_g=2.00
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_1/alpha_a_36.00_alpha_g_2.00/gml
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=36.00 | alpha_g=3.00
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_1/alpha_a_36.00_alpha_g_3.00/gml
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=36.00 | alpha_g=4.00
# [SKIP] sem .gml.gz: /home/light/Documents/SpatialPreferential/data/N_100000/m0_1/dim_1/alpha_a_36.00_alpha_g_4.00/gml
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=4.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=4.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=4.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=4.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=4.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=4.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=4.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=4.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=5.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=5.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=5.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=5.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=5.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=5.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=5.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=5.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=6.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=6.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=6.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=6.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=6.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=6.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=6.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=6.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=7.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=7.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=7.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=7.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=7.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=7.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=7.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=7.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=8.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=8.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=8.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=8.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=8.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=8.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=8.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=8.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=9.00 | alpha_g=1.00
# Extraindo (m0=1, dim=1, aa=9.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=9.00 | alpha_g=2.00
# Extraindo (m0=1, dim=1, aa=9.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=9.00 | alpha_g=3.00
# Extraindo (m0=1, dim=1, aa=9.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=1 | alpha_a=9.00 | alpha_g=4.00
# Extraindo (m0=1, dim=1, aa=9.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=0.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=0.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=0.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=0.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=0.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=0.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=0.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=0.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=1.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=1.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=1.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=1.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=1.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=1.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=1.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=1.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=10.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=10.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=10.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=10.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=10.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=10.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=10.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=10.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=12.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=12.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=12.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=12.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=12.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=12.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=12.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=12.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=14.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=14.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=14.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=14.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=14.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=14.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=14.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=14.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=15.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=15.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=15.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=15.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=15.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=15.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=15.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=15.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=16.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=16.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=16.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=16.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=16.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=16.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=16.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=16.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=18.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=18.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=18.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=18.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=18.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=18.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=18.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=18.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=2.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=2.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=2.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=2.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=2.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=2.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=2.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=2.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=20.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=20.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=20.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=20.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=20.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=20.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=20.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=20.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=21.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=21.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=21.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=21.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=21.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=21.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=21.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=21.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=24.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=24.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=24.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=24.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=24.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=24.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=24.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=24.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=27.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=27.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=27.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=27.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=27.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=27.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=27.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=27.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=28.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=28.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=28.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=28.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=28.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=28.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=28.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=28.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=3.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=3.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=3.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=3.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=3.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=3.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=3.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=3.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=32.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=32.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=32.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=32.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=32.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=32.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=32.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=32.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=36.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=36.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=36.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=36.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=36.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=36.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=36.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=36.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=4.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=4.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=4.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=4.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=4.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=4.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=4.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=4.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=5.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=5.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=5.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=5.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=5.00 | alpha_g=3.00
# Extraindo (m0=1, dim=2, aa=5.00, ag=3.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=5.00 | alpha_g=4.00
# Extraindo (m0=1, dim=2, aa=5.00, ag=4.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=6.00 | alpha_g=1.00
# Extraindo (m0=1, dim=2, aa=6.00, ag=1.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]
# [PROCESSANDO] N=100000 | m0=1 | dim=2 | alpha_a=6.00 | alpha_g=2.00
# Extraindo (m0=1, dim=2, aa=6.00, ag=2.00):   0%|          | 0/10 [00:00<?, ?arquivo/s]

# %%
remove_all_gml_gz("../../data")
# Out:
# [OK] Limpeza concluída
#      pastas_gml_verificadas=1136
#      arquivos_removidos=10100

# %%
ROOT = "../../data"   # ajuste para seu diretório base real

# 1) tudo numa pasta só
copy_all_parquet_flat_by_dim(ROOT)

# 2) espelhar árvore, mas só manifest + parquet
copy_tree_only_new_parquet(ROOT)
# Out:
# [OK] Flat copy by Dim -> /home/light/Documents/SpatialPreferential/Data_Tsallis
#      dirs_created=3 files_copied=578 skipped_pattern=0
# [OK] Mirrored tree (new parquet only) -> /home/light/Documents/SpatialPreferential/Data_Network
#      dirs_created=289 files_copied=578 skipped_pattern=0
